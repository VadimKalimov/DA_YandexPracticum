# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#Импортируем-библиотеки" data-toc-modified-id="Импортируем-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем библиотеки</a></span></li><li><span><a href="#Считаем-данные-из-файлов" data-toc-modified-id="Считаем-данные-из-файлов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Считаем данные из файлов</a></span></li><li><span><a href="#Выведим-первые-пять-строк" data-toc-modified-id="Выведим-первые-пять-строк-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Выведим первые пять строк</a></span></li><li><span><a href="#Переименуем-названия-столбцов,-приведем-их-к-общему-ввиду" data-toc-modified-id="Переименуем-названия-столбцов,-приведем-их-к-общему-ввиду-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Переименуем названия столбцов, приведем их к общему ввиду</a></span></li><li><span><a href="#Структура-visits,-данные-о-посещениях" data-toc-modified-id="Структура-visits,-данные-о-посещениях-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Структура visits, данные о посещениях</a></span></li><li><span><a href="#Структура-orders,-данные-о-заказах" data-toc-modified-id="Структура-orders,-данные-о-заказах-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Структура orders, данные о заказах</a></span></li><li><span><a href="#Структура-costs,-данные-о-расходах-на-рекламу" data-toc-modified-id="Структура-costs,-данные-о-расходах-на-рекламу-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Структура costs, данные о расходах на рекламу</a></span></li><li><span><a href="#Изучим-датафреймы-при-помощи-info" data-toc-modified-id="Изучим-датафреймы-при-помощи-info-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Изучим датафреймы при помощи info</a></span></li><li><span><a href="#Изменим-тип-данных,-связанных-с-датой,-с-object-на-date" data-toc-modified-id="Изменим-тип-данных,-связанных-с-датой,-с-object-на-date-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Изменим тип данных, связанных с датой, с object на date</a></span></li><li><span><a href="#Проверим-на-наличие-дубликатов" data-toc-modified-id="Проверим-на-наличие-дубликатов-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Проверим на наличие дубликатов</a></span></li><li><span><a href="#Изучим-информацию-в-датафреймах" data-toc-modified-id="Изучим-информацию-в-датафреймах-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Изучим информацию в датафреймах</a></span><ul class="toc-item"><li><span><a href="#Столбец-регион-из-данных-о-посещениях" data-toc-modified-id="Столбец-регион-из-данных-о-посещениях-1.11.1"><span class="toc-item-num">1.11.1&nbsp;&nbsp;</span>Столбец регион из данных о посещениях</a></span></li><li><span><a href="#Столбец-device-из-данных-о-посещениях" data-toc-modified-id="Столбец-device-из-данных-о-посещениях-1.11.2"><span class="toc-item-num">1.11.2&nbsp;&nbsp;</span>Столбец device из данных о посещениях</a></span></li><li><span><a href="#Cтолбец-channel-из-данных-о-посещениях" data-toc-modified-id="Cтолбец-channel-из-данных-о-посещениях-1.11.3"><span class="toc-item-num">1.11.3&nbsp;&nbsp;</span>Cтолбец channel из данных о посещениях</a></span></li></ul></li><li><span><a href="#Столбец-revenue-из-данных-о-заказах" data-toc-modified-id="Столбец-revenue-из-данных-о-заказах-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Столбец revenue из данных о заказах</a></span></li><li><span><a href="#Столбец-channel-из-данных-о-расходах-на-рекламу" data-toc-modified-id="Столбец-channel-из-данных-о-расходах-на-рекламу-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Столбец channel из данных о расходах на рекламу</a></span></li><li><span><a href="#Столбец-costs-из-данных-о-расходах-на-рекламу" data-toc-modified-id="Столбец-costs-из-данных-о-расходах-на-рекламу-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Столбец costs из данных о расходах на рекламу</a></span></li></ul></li><li><span><a href="#Зададим-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Зададим-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Напишем-функцию-для-создания-профилей-пользователей-get_profiles()" data-toc-modified-id="Напишем-функцию-для-создания-профилей-пользователей-get_profiles()-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Напишем функцию для создания профилей пользователей get_profiles()</a></span></li><li><span><a href="#Напишем-функцию-для-подсчёта-Retention-Rate,-коэффициент-удержания.-get_retention()" data-toc-modified-id="Напишем-функцию-для-подсчёта-Retention-Rate,-коэффициент-удержания.-get_retention()-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Напишем функцию для подсчёта Retention Rate, коэффициент удержания. get_retention()</a></span></li><li><span><a href="#Напишем-функцию-для-подсчёта-конверсии-get_conversion()" data-toc-modified-id="Напишем-функцию-для-подсчёта-конверсии-get_conversion()-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Напишем функцию для подсчёта конверсии get_conversion()</a></span></li><li><span><a href="#Напишем-функцию-для-подсчёта-LTV,-пожизненная-ценность-клиента.-get_ltv()" data-toc-modified-id="Напишем-функцию-для-подсчёта-LTV,-пожизненная-ценность-клиента.-get_ltv()-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Напишем функцию для подсчёта LTV, пожизненная ценность клиента. get_ltv()</a></span></li><li><span><a href="#Напишем-функцию-для-сглаживания-данных-filter_data()" data-toc-modified-id="Напишем-функцию-для-сглаживания-данных-filter_data()-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Напишем функцию для сглаживания данных filter_data()</a></span></li><li><span><a href="#Напишем-функцию-для-построения-графика-Retention-Rate.-plot_retention()" data-toc-modified-id="Напишем-функцию-для-построения-графика-Retention-Rate.-plot_retention()-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Напишем функцию для построения графика Retention Rate. plot_retention()</a></span></li><li><span><a href="#Напишем-функцию-для-построения-графика-конверсии.-plot_conversion()" data-toc-modified-id="Напишем-функцию-для-построения-графика-конверсии.-plot_conversion()-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Напишем функцию для построения графика конверсии. plot_conversion()</a></span></li><li><span><a href="#Напишем-функцию-для-построения-графика-визуализации-LTV-и-ROI.-plot_ltv_roi()" data-toc-modified-id="Напишем-функцию-для-построения-графика-визуализации-LTV-и-ROI.-plot_ltv_roi()-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Напишем функцию для построения графика визуализации LTV и ROI. plot_ltv_roi()</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Составим-профили-пользователей.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей." data-toc-modified-id="Составим-профили-пользователей.-Определим-минимальную-и-максимальную-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.</a></span></li><li><span><a href="#Выясним-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны." data-toc-modified-id="Выясним-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выясним из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.</a></span></li><li><span><a href="#Узнаем-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства." data-toc-modified-id="Узнаем-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Узнаем какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.</a></span></li><li><span><a href="#Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения." data-toc-modified-id="Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-общую-сумму-расходов-на-маркетинг." data-toc-modified-id="Посчитаем-общую-сумму-расходов-на-маркетинг.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посчитаем общую сумму расходов на маркетинг.</a></span></li><li><span><a href="#Выясним,-как-траты-распределены-по-рекламным-источникам,-то-есть-сколько-денег-потратили-на-каждый-источник" data-toc-modified-id="Выясним,-как-траты-распределены-по-рекламным-источникам,-то-есть-сколько-денег-потратили-на-каждый-источник-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник</a></span></li><li><span><a href="#Построим-визуализацию-динамики-изменения-расходов-во-времени-по-каждому-источнику." data-toc-modified-id="Построим-визуализацию-динамики-изменения-расходов-во-времени-по-каждому-источнику.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Построим визуализацию динамики изменения расходов во времени по каждому источнику.</a></span><ul class="toc-item"><li><span><a href="#Динамика-изменения-расходов-на-рекламу-по-месяцам-по-каналам." data-toc-modified-id="Динамика-изменения-расходов-на-рекламу-по-месяцам-по-каналам.-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Динамика изменения расходов на рекламу по месяцам по каналам.</a></span></li><li><span><a href="#Динамика-изменения-расходов-на-рекламу-по-неделям-по-каналам." data-toc-modified-id="Динамика-изменения-расходов-на-рекламу-по-неделям-по-каналам.-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Динамика изменения расходов на рекламу по неделям по каналам.</a></span></li></ul></li><li><span><a href="#Узнаем-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника." data-toc-modified-id="Узнаем-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Узнаем сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.</a></span></li></ul></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графиков-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графиков-динамики-LTV,-CAC-и-ROI.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения.-То-же-самое-сделаем-с-удержанием-пользователей.-Построим-и-изучим-графики-конверсии-и-удержания." data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения.-То-же-самое-сделаем-с-удержанием-пользователей.-Построим-и-изучим-графики-конверсии-и-удержания.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построим-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения-с-разбивкой-по-устройствам.-То-же-самое-сделаем-с-удержанием-пользователей.-Постройте-и-изучим-графики-конверсии-и-удержания." data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения-с-разбивкой-по-устройствам.-То-же-самое-сделаем-с-удержанием-пользователей.-Постройте-и-изучим-графики-конверсии-и-удержания.-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения с разбивкой по устройствам. То же самое сделаем с удержанием пользователей. Постройте и изучим графики конверсии и удержания.</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения-с-разбивкой-по-регионам.-То-же-самое-сделаем-с-удержанием-пользователей.-Постройте-и-изучим-графики-конверсии-и-удержания." data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения-с-разбивкой-по-регионам.-То-же-самое-сделаем-с-удержанием-пользователей.-Постройте-и-изучим-графики-конверсии-и-удержания.-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения с разбивкой по регионам. То же самое сделаем с удержанием пользователей. Постройте и изучим графики конверсии и удержания.</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения-с-разбивкой-по-рекламным-каналам.-То-же-самое-сделаем-с-удержанием-пользователей.-Постройте-и-изучим-графики-конверсии-и-удержания." data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения-с-разбивкой-по-рекламным-каналам.-То-же-самое-сделаем-с-удержанием-пользователей.-Постройте-и-изучим-графики-конверсии-и-удержания.-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения с разбивкой по рекламным каналам. То же самое сделаем с удержанием пользователей. Постройте и изучим графики конверсии и удержания.</a></span></li></ul></li><li><span><a href="#Напишите-выводы" data-toc-modified-id="Напишите-выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Напишите выводы</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></div>

# %% [markdown]
# # Маркетинговый анализ развлекательного приложения

# %% [markdown]
# Цель проекта:
#     Произвести маркетинговый анализ развлекательного приложения Procrastinate Pro+. Так как несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Необходимо разобраться в причинах и помочь компании выйти в плюс.
# Необходимо изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов,
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ### Загрузим данные и подготовим их к анализу

# %% [markdown]
# #### Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# #### Считаем данные из файлов

# %%
visits, orders, costs = (pd.read_csv('D:/DA/projects/visits_info_short.csv'),  
                         pd.read_csv('D:/DA/projects/orders_info_short.csv'),  
                         pd.read_csv('D:/DA/projects/costs_info_short.csv'))

# %% [markdown]
# #### Выведим первые пять строк

# %%
display(
    visits.head(),
    orders.head(),
    costs.head()
)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %% [markdown]
# #### Переименуем названия столбцов, приведем их к общему ввиду

# %% [markdown]
# Приведем к нижнему регистру

# %%
visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# %% [markdown]
# Уберем пробелы в названиях, приведем их к змеиному регистру

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns.values]

# %% [markdown]
# #### Структура visits, данные о посещениях

# %%
visits.sample()
# Out:
#             user_id  region  device             channel        session_start  \
# 296441  19247042676  France  iPhone  OppleCreativeMedia  2019-10-08 02:37:22
#
#                 session_end
# 296441  2019-10-08 02:49:20

# %% [markdown]
# - user_id — уникальный идентификатор пользователя,
# - region — страна пользователя,
# - device — тип устройства пользователя,
# - channel — идентификатор источника перехода,
# - session_start — дата и время начала сессии,
# - session_end — дата и время окончания сессии.

# %% [markdown]
# #### Структура orders, данные о заказах

# %%
orders.sample()
# Out:
#             user_id             event_dt  revenue
# 15113  870405517494  2019-08-30 17:55:21     4.99

# %% [markdown]
# - user_id — уникальный идентификатор пользователя,
# - event_dt — дата и время покупки,
# - revenue — сумма заказа.

# %% [markdown]
# #### Структура costs, данные о расходах на рекламу

# %%
costs.sample()
# Out:
#              dt       channel  costs
# 316  2019-09-14  MediaTornado   5.76

# %% [markdown]
# - dt — дата проведения рекламной кампании,
# - channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.

# %% [markdown]
# #### Изучим датафреймы при помощи info

# %%
visits.info()
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# **Из данных видим, что все значения в таблицах не нулевые, тем не менее проверим на пропуски**

# %%
visits.isna().mean().round(4).to_frame().sort_values(by=0).style.format('{:.2%}').background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_c75d4_row0_col0, #T_c75d4_row1_col0, #T_c75d4_row2_col0, #T_c75d4_row3_col0, #T_c75d4_row4_col0, #T_c75d4_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c75d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c75d4_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c75d4_level0_row0" class="row_heading level0 row0" >user_id</th>
#       <td id="T_c75d4_row0_col0" class="data row0 col0" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c75d4_level0_row1" class="row_heading level0 row1" >region</th>
#       <td id="T_c75d4_row1_col0" class="data row1 col0" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c75d4_level0_row2" class="row_heading level0 row2" >device</th>
#       <td id="T_c75d4_row2_col0" class="data row2 col0" >0.00%</td>
#     </tr>
#     <tr>
# ...

# %%
orders.isna().mean().round(4).to_frame().sort_values(by=0).style.format('{:.2%}').background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_3c80e_row0_col0, #T_3c80e_row1_col0, #T_3c80e_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3c80e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c80e_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c80e_level0_row0" class="row_heading level0 row0" >user_id</th>
#       <td id="T_3c80e_row0_col0" class="data row0 col0" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_3c80e_level0_row1" class="row_heading level0 row1" >event_dt</th>
#       <td id="T_3c80e_row1_col0" class="data row1 col0" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_3c80e_level0_row2" class="row_heading level0 row2" >revenue</th>
#       <td id="T_3c80e_row2_col0" class="data row2 col0" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
costs.isna().mean().round(4).to_frame().sort_values(by=0).style.format('{:.2%}').background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_4ff8d_row0_col0, #T_4ff8d_row1_col0, #T_4ff8d_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4ff8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ff8d_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ff8d_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_4ff8d_row0_col0" class="data row0 col0" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4ff8d_level0_row1" class="row_heading level0 row1" >channel</th>
#       <td id="T_4ff8d_row1_col0" class="data row1 col0" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_4ff8d_level0_row2" class="row_heading level0 row2" >costs</th>
#       <td id="T_4ff8d_row2_col0" class="data row2 col0" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Изменим тип данных, связанных с датой, с object на date

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# #### Проверим на наличие дубликатов

# %%
display(
    visits.duplicated().sum(), 
    orders.duplicated().sum(),
    costs.duplicated().sum()
)
# Out:
# 0
# 0
# 0

# %% [markdown]
# Дубликатов нет

# %% [markdown]
# #### Изучим информацию в датафреймах

# %% [markdown]
# ##### Столбец регион из данных о посещениях

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %% [markdown]
# Видим, что пользователи из США, Великобритании, Франции и Германии

# %%
visits['region'].value_counts().to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# #T_bb842_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bb842_row1_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_bb842_row2_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_bb842_row3_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_bb842">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb842_level0_col0" class="col_heading level0 col0" >region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb842_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_bb842_row0_col0" class="data row0 col0" >207327</td>
#     </tr>
#     <tr>
#       <th id="T_bb842_level0_row1" class="row_heading level0 row1" >UK</th>
#       <td id="T_bb842_row1_col0" class="data row1 col0" >36419</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ##### Столбец device из данных о посещениях

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['device'].value_counts().to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# #T_1183b_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1183b_row1_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_1183b_row2_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1183b_row3_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_1183b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1183b_level0_col0" class="col_heading level0 col0" >device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1183b_level0_row0" class="row_heading level0 row0" >iPhone</th>
#       <td id="T_1183b_row0_col0" class="data row0 col0" >112603</td>
#     </tr>
#     <tr>
#       <th id="T_1183b_level0_row1" class="row_heading level0 row1" >Android</th>
#       <td id="T_1183b_row1_col0" class="data row1 col0" >72590</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ##### Cтолбец channel из данных о посещениях

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
visits['channel'].value_counts().to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# #T_8e5d4_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8e5d4_row1_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_8e5d4_row2_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_8e5d4_row3_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_8e5d4_row4_col0, #T_8e5d4_row5_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_8e5d4_row6_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_8e5d4_row7_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_8e5d4_row8_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_8e5d4_row9_col0, #T_8e5d4_row10_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_8e5d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e5d4_level0_col0" class="col_heading level0 col0" >channel</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %% [markdown]
# #### Столбец revenue из данных о заказах

# %%
orders['revenue'].hist(bins=10, figsize = (10, 5))
plt.show()

# %%
orders['revenue'].describe()
# Out:
# count    40212.000000
# mean         5.370608
# std          3.454208
# min          4.990000
# 25%          4.990000
# 50%          4.990000
# 75%          4.990000
# max         49.990000
# Name: revenue, dtype: float64

# %% [markdown]
# Медиана суммы заказов равна 4.99

# %% [markdown]
# #### Столбец channel из данных о расходах на рекламу

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %%
costs['channel'].value_counts().to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# #T_25f7e_row0_col0, #T_25f7e_row1_col0, #T_25f7e_row2_col0, #T_25f7e_row3_col0, #T_25f7e_row4_col0, #T_25f7e_row5_col0, #T_25f7e_row6_col0, #T_25f7e_row7_col0, #T_25f7e_row8_col0, #T_25f7e_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_25f7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25f7e_level0_col0" class="col_heading level0 col0" >channel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25f7e_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#       <td id="T_25f7e_row0_col0" class="data row0 col0" >180</td>
#     </tr>
#     <tr>
#       <th id="T_25f7e_level0_row1" class="row_heading level0 row1" >MediaTornado</th>
#       <td id="T_25f7e_row1_col0" class="data row1 col0" >180</td>
#     </tr>
#     <tr>
#       <th id="T_25f7e_level0_row2" class="row_heading level0 row2" >RocketSuperAds</th>
# ...

# %% [markdown]
# #### Столбец costs из данных о расходах на рекламу

# %%
costs['costs'].hist(bins=10, figsize = (10, 5))
plt.show()

# %%
costs['costs'].describe()
# Out:
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %% [markdown]
# Медиана расходов на рекламу составляет 12.285. Для каждагого канала было заказано 180 рекламных кампаний.

# %% [markdown]
# Общее описание:
#    1. visits - данные о посещениях:
#     - user_id — уникальный идентификатор пользователя,
#     - region — страна пользователя,
#     - device — тип устройства пользователя,
#     - channel — идентификатор источника перехода,
#     - session_start — дата и время начала сессии,
#     - session_end — дата и время окончания сессии.
#
#    2. orders - данные о заказах:
#    - user_id — уникальный идентификатор пользователя,
#    - event_dt — дата и время покупки,
#    - revenue — сумма заказа.
#
#    3. costs - данные о расходах на рекламные кампании:
#    - dt — дата проведения рекламной кампании,
#    - channel — идентификатор рекламного источника,
#    - costs — расходы на эту кампанию.
#
# Выводы:
#  1. Выяснили, что пропусков и дубликатов в данных нет.
#  2. Привели названия столбцов к общей стилистике.
#  3. У данных, связанных с датами, изменили тип с object на datetime
#  4. Выяснили, что в данных представлены пользователи из США, Великобритании, Франции и Германии. Но больше всего посещений было выполнено из США.
#  5. Пользователи используют 4 типа девайса: iphone, android, PC, Mac. Больше всего посещений зафиксировано с iphone.
#  6. Топ 3 канала перехода: Естественный канал, Tip Top, FaceBoom. Больше всего органических посещений.
#  7. Медианное значение суммы заказов равно 4.99. А среднее 5.37.
#  8. Выяснили, что на каждый канал в рамках размещения рекламы приходится одинаковое число кампаний = 180.
#  9. Медианное значение расходов на рекламную кампанию 12.285, а среднее 58.609.

# %% [markdown]
# ### Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Используем функции, с которыми познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# #### Напишем функцию для создания профилей пользователей get_profiles()

# %%
def get_profiles(sessions, orders, ad_costs):

    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
    
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
   
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### Напишем функцию для подсчёта Retention Rate, коэффициент удержания. get_retention()

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    
    dimensions = ['payer'] + dimensions
   
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days
    
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result
    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )
    
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Напишем функцию для подсчёта конверсии get_conversion()

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )
    
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']
    
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
       
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

   
    if 'cohort' in dimensions: 
        dimensions = []

    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Напишем функцию для подсчёта LTV, пожизненная ценность клиента. get_ltv()

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    
    def group_by_dimensions(df, dims, horizon_days):
        
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        
        result = result.fillna(0).cumsum(axis=1)
        
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
       
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        
        result = result.div(result['cohort_size'], axis=0)
        
        result = result[['cohort_size'] + list(range(horizon_days))]
        
        result['cohort_size'] = cohort_sizes
        
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()
        
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )
       
        roi = result.div(cac['cac'], axis=0)
        
        roi = roi[~roi['cohort_size'].isin([np.inf])]
        
        roi['cohort_size'] = cohort_sizes

        roi['cac'] = cac['cac']
        
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        
        return result, roi

    
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    
    if 'cohort' in dimensions:
        dimensions = []

    
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw, 
        result_grouped,  
        result_in_time,  
        roi_grouped, 
        roi_in_time,  
    )

# %% [markdown]
# #### Напишем функцию для сглаживания данных filter_data()

# %%
def filter_data(df, window):
    
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### Напишем функцию для построения графика Retention Rate. plot_retention()

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    
    plt.figure(figsize=(15, 10))

    
    retention = retention.drop(columns=['cohort_size', 0])
    
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

   
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    
    ax3 = plt.subplot(2, 2, 3)
   
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Напишем функцию для построения графика конверсии. plot_conversion()

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

  
    plt.figure(figsize=(15, 5))

    
    conversion = conversion.drop(columns=['cohort_size'])
    
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Напишем функцию для построения графика визуализации LTV и ROI. plot_ltv_roi()

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    
    plt.figure(figsize=(20, 10))

    
    ltv = ltv.drop(columns=['cohort_size'])
   
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

   
    cac_history = roi_history[['cac']]

    
    roi = roi.drop(columns=['cohort_size', 'cac'])
   
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

   
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

   
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# #### Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.

# %%
profiles = get_profiles(visits, orders, costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %%
profiles['dt'].min()
# Out:
# datetime.date(2019, 5, 1)

# %%
profiles['dt'].max()
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# Даты совпадают с датами из ТЗ - 1 мая по 27 октября 2019 года

# %% [markdown]
# **Если говорить о профиле пользователя, то у нас есть 150 008 уникальных пользователей. О которых нам известно: дата и время первого посещения, канал откуда пришел пользователь, тип устройства с которого заходит в приложение, регион проживания, платящий пользователь или нет, а также стоимость его привлечения.
# Также мы определили, что данные предоставлены с 01 мая 2019г. по 27 октября 2019 г.**

# %% [markdown]
# #### Выясним из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %% [markdown]
# Напишем функцию для построения таблицы

# %%
def profiles_sorting(element):
    profiles_sorting = pd.DataFrame()
    profiles_sorting['sum_users'] = profiles.groupby(element)['user_id'].count()
    profiles_sorting['payer_sum_users'] = profiles.query('payer == True').groupby(element)['user_id'].count()
    profiles_sorting['share_of_paying'] = 100*(profiles_sorting['payer_sum_users'] / profiles_sorting['sum_users'])
    profiles_sorting = profiles_sorting.sort_values(by='share_of_paying', ascending=False).style.format({'share_of_paying': '{:.2f}%'}).background_gradient()
    return profiles_sorting

# %%
profiles_sorting('region')
# Out:
# <style type="text/css">
# #T_38ee0_row0_col0, #T_38ee0_row0_col1, #T_38ee0_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_38ee0_row1_col0, #T_38ee0_row1_col1, #T_38ee0_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_38ee0_row1_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_38ee0_row2_col0, #T_38ee0_row3_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_38ee0_row2_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_38ee0_row2_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_38ee0_row3_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_38ee0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38ee0_level0_col0" class="col_heading level0 col0" >sum_users</th>
#       <th id="T_38ee0_level0_col1" class="col_heading level0 col1" >payer_sum_users</th>
# ...

# %% [markdown]
# **Больше всего пользователей приходят в приложение из США 100 002 пользователей, в то время как из Германии, Великобритании и Франции вместе взятых всего 50 006. Справедливости ради, в США и население больше. США 301 млн., Германия 83 млн., Великобритания 67 млн., Франция 64 млн.
# Доля платящих пользователей больше в США, 6.9%!**

# %% [markdown]
# #### Узнаем какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
profiles_sorting('device')
# Out:
# <style type="text/css">
# #T_ba849_row0_col0, #T_ba849_row3_col1, #T_ba849_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ba849_row0_col1, #T_ba849_row2_col0 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_ba849_row0_col2, #T_ba849_row1_col0, #T_ba849_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ba849_row1_col2 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_ba849_row2_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_ba849_row2_col2 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_ba849_row3_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_ba849">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba849_level0_col0" class="col_heading level0 col0" >sum_users</th>
#       <th id="T_ba849_level0_col1" class="col_heading level0 col1" >payer_sum_users</th>
# ...

# %% [markdown]
# **Большое количество пользователей используют iPhone. При этом доля платящих пользователей с iPhone 6.21%. Примерно, такая же доля платящих пользователй, которые используют Mac, 6.36%.**

# %% [markdown]
# #### Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
profiles_sorting('channel')
# Out:
# <style type="text/css">
# #T_f2e59_row0_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_f2e59_row0_col1, #T_f2e59_row0_col2, #T_f2e59_row10_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f2e59_row1_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_f2e59_row1_col1, #T_f2e59_row5_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_f2e59_row1_col2 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_f2e59_row2_col0, #T_f2e59_row6_col1, #T_f2e59_row7_col1, #T_f2e59_row10_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f2e59_row2_col1, #T_f2e59_row9_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_f2e59_row2_col2 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_f2e59_row3_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_f2e59_row3_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_f2e59_row3_col2 {
# ...

# %% [markdown]
# **Видим явного лидера и по количеству привлеченных пользователей и доле платящих, это FaceBoom. Если выделить топ-5: FaceBoom, AdNonSense, lambdaMediaAds, TipTop, RocketSuperAds.**

# %% [markdown]
# **Выводы:**
#    - У нас для анализа есть данные о 150 008 уникальных пользователях. А именно: дата и время первого посещения, канал откуда пришел пользователь, тип устройства с которого заходит в приложение, регион проживания, платящий пользователь или нет, а также стоимость его привлечения.
#    - Данные представлены  01 мая 2019г. по 27 октября 2019 г., что соответствует ТЗ.
#    - Выяснили, что больше всего пользователей из США. Доля платящих пользователей больше у США 6.9%
#    - Большое количество пользователей используют iPhone - 54 479. На втором месте Android - 35 032. При этом доля платящих пользователей с iPhone 6.21%. Примерно, такая же доля платящих пользователй, которые используют Mac, 6.36%.
#    - Видим, что органических пользователей больше всего - 56 439. Если брать ТОП-5 по количеству привлеченных пользователей, то это: FaceBoom - 29 144, TipTop - 19 561, OppleCreativeMedia - 8605, LeapBob - 8 553, WahooNetBanner - 8 553. Если брать ТОП-3 по доле платящих пользователей, то это: FaceBoom - 12.20%, AdNonSense - 11.34%, lambdaMediaAds - 10,47%

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# #### Посчитаем общую сумму расходов на маркетинг.

# %%
costs['costs'].sum().round()
# Out:
# 105497.0

# %% [markdown]
# Общая сумма расходов равна 105 497

# %% [markdown]
# #### Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник

# %%
costs.groupby('channel')['costs'].sum().sort_values(ascending=False).to_frame().style.format({'costs': '{:.2f}'}).background_gradient()
# Out:
# <style type="text/css">
# #T_a6cee_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a6cee_row1_col0 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_a6cee_row2_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a6cee_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a6cee_row4_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a6cee_row5_col0, #T_a6cee_row6_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a6cee_row7_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_a6cee_row8_col0, #T_a6cee_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_a6cee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6cee_level0_col0" class="col_heading level0 col0" >costs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >channel</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# **Видим, что наибольшие вложения приходятся на два источника. Это TipTop 54 751 и FaceBoom 32 445.**

# %% [markdown]
# #### Построим визуализацию динамики изменения расходов во времени по каждому источнику.

# %% [markdown]
# ##### Динамика изменения расходов на рекламу по месяцам по каналам.

# %%
costs['month'] = costs['dt'].astype('datetime64[M]')
costs_grouped = costs.pivot_table(index='month', columns = 'channel', values='costs', aggfunc='sum')
costs_grouped.plot(grid=True, figsize=(20, 9))
plt.title('Динамика изменения расходов по месяцам по каждому источнику')
plt.xlabel('Дата')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# **Для источника TipTop в течение периода бюджет увеличивается. Для FaceBoom бюджет несколько вырос, но он стабилен.**

# %% [markdown]
# ##### Динамика изменения расходов на рекламу по неделям по каналам.

# %%
costs['week'] = costs['dt'].astype('datetime64[W]')
costs_grouped = costs.pivot_table(index='week', columns = 'channel', values='costs', aggfunc='sum')
costs_grouped.plot(grid=True, figsize=(20, 9), )
plt.title('Динамика изменения расходов по неделям по каждому источнику')
plt.xlabel('Дата')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# **На этом графике также видем, что бюджет для источника TipTop в течение периода увеличивается. В конце периода видим уменьшение расходов.**

# %% [markdown]
# #### Узнаем сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
profiles_sorted = profiles.groupby('channel')['acquisition_cost'].mean() \
.sort_values(ascending=False) \
.to_frame() \
.style.format({'acquisition_cost': '{:.2f}'}) \
.background_gradient()

# %%
profiles_sorted
# Out:
# <style type="text/css">
# #T_2978e_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2978e_row1_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_2978e_row2_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_2978e_row3_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_2978e_row4_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_2978e_row5_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_2978e_row6_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2978e_row7_col0, #T_2978e_row8_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_2978e_row9_col0 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_2978e_row10_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2978e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# **Средний САС по проекту:**

# %%
profiles['acquisition_cost'].mean()
# Out:
# 0.7032778251827625

# %% [markdown]
# **Самый дорогой пользователь, это пользователь из TipTop.
# Стоит обратить внимание на распределение средств между разными источниками. Так по расходам есть явный лидер - TipTop. Но при этом FaceBoom опережает TipTop как по количетсву привлеченных пользователей, так и по доле платящих пользователей. При этом у двух источников AdNonSense и lambdaMediaAds не плохие показатели по доле платящих пользователей. При этом привлечение в этих каналах обходится дешевле.**

# %% [markdown]
# **Выводы:**
#   - Общая сумма расходов на маркетинг = 105497.0
#   - ТОП-3 истоника по расходам: TipTop - 54751.30, FaceBoom - 32445.60, WahooNetBanner - 5151.00
#   - На помесячном и понедельном графике расходов виден рост расходов по источнику TipTop
#   - ТОП-3 источника по средней стоимости привлечения одного пользователя: TipTop - 2.80, FaceBoom - 1.11, AdNonSense - 1.01
#   - Средний САС по проекту равен 0.703

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# **Считаем, что на календаре 1 ноября 2019**

# %%
observation_date = datetime(2019, 11, 1).date()

# %% [markdown]
# **Горизонт анализа**

# %%
horizon_days = 14

# %% [markdown]
# #### Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.

# %% [markdown]
# Органических пользователей исключим из анализа, так как из-за них графики могут получиться смещенными. А наша задача проанализировать окупаемость рекламы.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history= get_ltv(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, 14, window=10)

# %% [markdown]
# - Реклама не окупается. На 13 день ROI около 80%
# - CAC не стабилен. Дело в увелечении рекламного бюджета.
# - LTV стабильно растет.

# %% [markdown]
# #### Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)
plot_conversion(conversion_grouped, conversion_in_time, horizon_days, window=10)

# %% [markdown]
# - Конверсия растет

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(
    profiles.query('channel != "organic"'),
    visits,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)
plot_retention(retention_grouped, retention_in_time, horizon_days, window=20)

# %% [markdown]
# Вроде все в порядке:
# - Удержание убывает по экспоненциальному закону.
# - Удержание неплатящих убывает быстрее, чем удержание платящих.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
ltv_device, ltv_grouped_device, ltv_history_device, roi_grouped_device, roi_history_device = get_ltv(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)

# %%
plot_ltv_roi(ltv_grouped_device, ltv_history_device, roi_grouped_device, roi_history_device, 14, window=14)

# %% [markdown]
# - LTV растет
# - САС не стабилен. У Мас и IPhone САС значительно выше, нежели у РС
# - ROI. На 12 день РС выходит на окупаемость.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
ltv_device, ltv_grouped_device, ltv_history_device, roi_grouped_device, roi_history_device = get_ltv(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)

# %%
plot_ltv_roi(ltv_grouped_device, ltv_history_device, roi_grouped_device, roi_history_device, 14, window=14)

# %% [markdown]
# - LTV у США повыше.
# - САС у США очень высокий. Виден явный перекос в маркетинговой стратегии.
# - ROI. Реклама по США не окупаются.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
ltv_device, ltv_grouped_device, ltv_history_device, roi_grouped_device, roi_history_device = get_ltv(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)
plot_ltv_roi(ltv_grouped_device, ltv_history_device, roi_grouped_device, roi_history_device, 14, window=14)

# %% [markdown]
# - LTV получше у источников lambdaMediaAds и TipTop
# - Очень высокий САС у TipTop
# - Не окупается реклама у TipTop, FaceBoom и AdNonSense

# %% [markdown]
# #### Проверим конверсию пользователей и динамику её изменения с разбивкой по устройствам. То же самое сделаем с удержанием пользователей. Постройте и изучим графики конверсии и удержания.

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)
plot_conversion(conversion_grouped, conversion_in_time, horizon_days, window=10)

# %% [markdown]
# **Пользователи IPhone и Mac конвертируются лучше. Хуже всего с коверсией у РС.**

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(
    profiles.query('channel != "organic"'),
    visits,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)
plot_retention(retention_grouped, retention_in_time, horizon_days, window=20)

# %% [markdown]
# **По удержанию нет явных лидеров, чуть лучше удерживаются пользователи РС.**

# %% [markdown]
# #### Проверим конверсию пользователей и динамику её изменения с разбивкой по регионам. То же самое сделаем с удержанием пользователей. Постройте и изучим графики конверсии и удержания.

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)
plot_conversion(conversion_grouped, conversion_in_time, horizon_days, window=10)

# %% [markdown]
# **Лучше конвертируются пользователи из США**

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(
    profiles.query('channel != "organic"'),
    visits,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)
plot_retention(retention_grouped, retention_in_time, horizon_days, window=20)

# %% [markdown]
# **Пользователи из США хуже всего удерживаютсся**

# %% [markdown]
# #### Проверим конверсию пользователей и динамику её изменения с разбивкой по рекламным каналам. То же самое сделаем с удержанием пользователей. Постройте и изучим графики конверсии и удержания.

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(
    profiles.query('channel != "organic"'),
    orders,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)
plot_conversion(conversion_grouped, conversion_in_time, horizon_days, window=10)

# %% [markdown]
# **ТОП-3 источника по конверсии: FaceBoom, AdNonSense, lambdaMediaAds**

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(
    profiles.query('channel != "organic"'),
    visits,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)
plot_retention(retention_grouped, retention_in_time, horizon_days, window=20)

# %% [markdown]
# **Хуже всего удерживаются пользователи из AdNonSense и FaceBoom**

# %% [markdown]
# ### Выводы:
# 1. В целом реклама не окупается:
#    - На 13 день ROI около 80%.
#    - CAC не стабилен. Дело в увелечении рекламного бюджета.
#    - LTV стабильно растет.
#    - Конверсия растет
#    - Удержание убывает по экспоненциальному закону.
#    - Удержание неплатящих убывает быстрее, чем удержание платящих.
#
#
# 2. Анализ с разбивкой по устройствам:
#    - LTV растет
#    - САС не стабилен. У Мас и IPhone САС значительно выше, нежели у РС
#    - ROI. На 12 день РС выходит на окупаемость.
#    - Пользователи IPhone и Mac конвертируются лучше. Хуже всего с коверсией у РС.
#    - По удержанию нет явных лидеров, чуть лучше удерживаются пользователи РС.
#
#
# 3. Анализ с разбивкой по регионам:
#    - LTV у США повыше.
#    - САС у США очень высокий. Виден явный перекос в маркетинговой стратегии.
#    - ROI. Реклама по США не окупаются.
#    - Лучше конвертируются пользователи из США.
#    - Пользователи из США хуже всего удерживаютсся.
#
#
# 4. Анализ с разбивкой по рекламным каналам:
#    - LTV получше у источников lambdaMediaAds и TipTop
#    - Очень высокий САС у TipTop
#    - Не окупается реклама у TipTop, FaceBoom и AdNonSense
#    - ТОП-3 источника по конверсии: FaceBoom, AdNonSense, lambdaMediaAds.
#    - Хуже всего удерживаются пользователи из AdNonSense и FaceBoom.
#
# Рекомендации для отдела маркетинга:
#  - Необходимо перераспределение рекламного бюджета. Стратегия заливание деньгами одного канала себя не оправдала. Необходимо рассмотреть и другие каналы для привлечения. Например lambdaMediaAds, RocketSuperAds, WahooNetBanner. У этих платформ неплохой показатель роста LTV.
#  - Необходимо обратить внимание на пользователей из США. Так как пользователи из США конвертируются лучше всех, но они же и хуже всех удерживаются. Возможно мы охватываем не нашу возрастную категорию. Наврятли это техническая ошибка. Так как удержание по устройствам примерно одинаковое. Возможно канал TipTop используют молодые клиенты, школьники и студенты, у которых платежеспособность в целом ниже.
